# %%
import plotly.express as px
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
from jupyter_dash import JupyterDash

# %% [markdown]
# ##### set up the server

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = JupyterDash(__name__, external_stylesheets=external_stylesheets)

# Create server variable with Flask server object for use with gunicorn
server = app.server

# %% [markdown]
# ### create layout

# %%
app.layout = html.Div([
    html.H2('Pandemic Impact on Economy:'), 
    html.Div([
        html.Label('Country:'),
        dcc.Checklist(
            id = 'country',
            options=[
                {'label': 'China', 'value': 'China'},
                {'label': 'United States', 'value': 'US'},
                {'label': 'New Zealand', 'value': 'NZ'}
            ],
            value=['China', 'US','NZ'],
            labelStyle={'display': 'inline-block'}
        )]),
     html.Div([
        dcc.Checklist(
            id = 'options',
            options=[
                {'label': 'Totoal cases', 'value': 'total_cases'},
                {'label': 'Total_deaths', 'value': 'total_deaths'},
                {'label': 'Stock index', 'value': 'index'}
            ],
            value=['total_cases', 'total_deaths','index'],
        )]),
    html.Div([
        dcc.Graph(id = "the graph")
    ])
    
])



@app.callback(
    output('the graph','figure' ),
    [input('country','value'),
    input('options','value')]
)
def update_graph(country,option):
# Out:
#   File "<ipython-input-63-358c2c089379>", line 38
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
app.run_server(mode = "inline")
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Data source: directly from the notebook in kaggle.com,which is provieded by Johns Hopkins University.
# ### https://www.kaggle.com/therealcyberlord/coronavirus-covid-19-visualization-prediction
# ### Reading world's COVID-19 data.

# %%
df = pd.read_csv('covid-data.csv', index_col = 3, parse_dates = True)
df
# Out:
#            iso_code continent     location  total_cases  new_cases  \
# date
# 2020-02-24      AFG      Asia  Afghanistan          1.0        1.0
# 2020-02-25      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-26      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-27      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-28      AFG      Asia  Afghanistan          1.0        0.0
# ...             ...       ...          ...          ...        ...
# 2021-04-13      ZWE    Africa     Zimbabwe      37330.0       23.0
# 2021-04-14      ZWE    Africa     Zimbabwe      37369.0       39.0
# 2021-04-15      ZWE    Africa     Zimbabwe      37422.0       53.0
# 2021-04-16      ZWE    Africa     Zimbabwe      37534.0      112.0
# 2021-04-17      ZWE    Africa     Zimbabwe      37699.0      165.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %% [markdown]
# ### COVID-19 data of NZ

# %%
NZ = df.loc[df['location'] == "New Zealand"][['total_cases', 'total_deaths']]

# %%
#fill the NaN value to be 0
_ = NZ.fillna(0,inplace = True)

# %%
NZ
# Out:
#             total_cases  total_deaths
# date
# 2020-02-28          1.0           0.0
# 2020-02-29          1.0           0.0
# 2020-03-01          1.0           0.0
# 2020-03-02          1.0           0.0
# 2020-03-03          1.0           0.0
# ...                 ...           ...
# 2021-04-13       2589.0          26.0
# 2021-04-14       2591.0          26.0
# 2021-04-15       2591.0          26.0
# 2021-04-16       2591.0          26.0
# 2021-04-17       2595.0          26.0
#
# [415 rows x 2 columns]

# %% [markdown]
# ### COVID-19 data of China

# %%
China = df.loc[df['location'] == 'China'][['total_cases', 'total_deaths']]

# %%
China
# Out:
#             total_cases  total_deaths
# date
# 2020-01-22        548.0          17.0
# 2020-01-23        643.0          18.0
# 2020-01-24        920.0          26.0
# 2020-01-25       1406.0          42.0
# 2020-01-26       2075.0          56.0
# ...                 ...           ...
# 2021-04-13     102103.0        4844.0
# 2021-04-14     102118.0        4845.0
# 2021-04-15     102135.0        4845.0
# 2021-04-16     102167.0        4845.0
# 2021-04-17     102201.0        4845.0
#
# [452 rows x 2 columns]

# %% [markdown]
# ### COVID-19 data of US

# %%
US = df.loc[df['location']=='United States'][['total_cases', 'total_deaths']]

# %%
#fill the NaN value to be 0
_ = US.fillna(0,inplace = True)

# %%
US
# Out:
#             total_cases  total_deaths
# date
# 2020-01-22          1.0           0.0
# 2020-01-23          1.0           0.0
# 2020-01-24          2.0           0.0
# 2020-01-25          2.0           0.0
# 2020-01-26          5.0           0.0
# ...                 ...           ...
# 2021-04-13   31345985.0      563446.0
# 2021-04-14   31421360.0      564402.0
# 2021-04-15   31495649.0      565289.0
# 2021-04-16   31575640.0      566224.0
# 2021-04-17   31627701.0      566904.0
#
# [452 rows x 2 columns]
